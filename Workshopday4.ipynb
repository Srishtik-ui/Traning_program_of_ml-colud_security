# %% [markdown]
# <a href="https://colab.research.google.com/github/Srishtik-ui/Traning_program_of_ml-colud_security/blob/main/Workshopday4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("/content/big_mart_sales_delimiter.csv")
df
# Out:
#     Item_Identifier\tItem_Weight\tItem_Fat_Content\tItem_Visibility\tItem_Type\tItem_MRP\tOutlet_Identifier\tOutlet_Establishment_Year\tOutlet_Size\tOutlet_Location_Type\tOutlet_Type\tItem_Outlet_Sales
# 0    FDA15\t9.3\tLow Fat\t0.016047301\tDairy\t249.8...
# 1    DRC01\t5.92\tRegular\t0.019278216\tSoft Drinks...
# 2    FDN15\t17.5\tLow Fat\t0.016760075\tMeat\t141.6...
# 3    FDX07\t19.2\tRegular\t0.0\tFruits and Vegetabl...
# 4    NCD19\t8.93\tLow Fat\t0.0\tHousehold\t53.8614\...
# ..                                                 ...
# 96   FDF41\t12.15\tLow Fat\t0.131383762\tFrozen Foo...
# 97   FDB56\t8.75\tRegular\t0.07461309\tFruits and V...
# 98   NCP18\t\tLow Fat\t0.028459761\tHousehold\t149....
# 99   FDB56\t8.75\tRegular\t0.07462720099999999\tFru...
# 100  FDT28\t13.3\tLow Fat\t0.063695084\tFrozen Food...
#
# [101 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content',
#        'Item_Visibility'],
#       dtype='object')

# %%
df = pd.read_csv("/content/big_mart_sales_delimiter.csv", delimiter = "\t",nrows = 50)
df
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %%
df = pd.read_csv("/content/big_mart_sales_delimiter.csv", delimiter = "\t",nrows = 50,skiprows = 10)
df
# Out:
#     FDU28    19.2  Regular  0.09444959           Frozen Foods  187.8214  \
# 0   FDY07  11.800  Low Fat    0.000000  Fruits and Vegetables   45.5402
# 1   FDA03  18.500  Regular    0.045464                  Dairy  144.1102
# 2   FDX32  15.100  Regular    0.100014  Fruits and Vegetables  145.4786
# 3   FDS46  17.600  Regular    0.047257            Snack Foods  119.6782
# 4   FDF32  16.350  Low Fat    0.068024  Fruits and Vegetables  196.4426
# 5   FDP49   9.000  Regular    0.069089              Breakfast   56.3614
# 6   NCB42  11.800  Low Fat    0.008596     Health and Hygiene  115.3492
# 7   FDP49   9.000  Regular    0.069196              Breakfast   54.3614
# 8   DRI11     NaN  Low Fat    0.034238            Hard Drinks  113.2834
# 9   FDU02  13.350  Low Fat    0.102492                  Dairy  230.5352
# 10  FDN22  18.850  Regular    0.138190            Snack Foods  250.8724
# 11  FDW12     NaN  Regular    0.035400           Baking Goods  144.5444
# ...

# %%
df = pd.read_csv("/content/big_mart_sales_delimiter.csv", delimiter = "\t",nrows = 50,skiprows = 10 )
df.head(20)
# Out:
#     FDU28    19.2  Regular  0.09444959           Frozen Foods  187.8214  \
# 0   FDY07  11.800  Low Fat    0.000000  Fruits and Vegetables   45.5402
# 1   FDA03  18.500  Regular    0.045464                  Dairy  144.1102
# 2   FDX32  15.100  Regular    0.100014  Fruits and Vegetables  145.4786
# 3   FDS46  17.600  Regular    0.047257            Snack Foods  119.6782
# 4   FDF32  16.350  Low Fat    0.068024  Fruits and Vegetables  196.4426
# 5   FDP49   9.000  Regular    0.069089              Breakfast   56.3614
# 6   NCB42  11.800  Low Fat    0.008596     Health and Hygiene  115.3492
# 7   FDP49   9.000  Regular    0.069196              Breakfast   54.3614
# 8   DRI11     NaN  Low Fat    0.034238            Hard Drinks  113.2834
# 9   FDU02  13.350  Low Fat    0.102492                  Dairy  230.5352
# 10  FDN22  18.850  Regular    0.138190            Snack Foods  250.8724
# 11  FDW12     NaN  Regular    0.035400           Baking Goods  144.5444
# ...

# %%
dfrom google.colab import drive
drive.mount('/content/drive')

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# Read the specific column only taking first 50 row using index value
df = pd.read_csv("/content/big_mart_sales_delimiter.csv", delimiter = "\t", usecols = [0,1,2,3],nrows = 50)
df
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %%
# Read the specific column only taking first 50 row using columns names
df = pd.read_csv("/content/big_mart_sales_delimiter.csv", delimiter = "\t", usecols = ['Item_Identifier','Item_Weight','Item_Fat_Content'],nrows = 50)

df
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content
# 0            FDA15        9.300          Low Fat
# 1            DRC01        5.920          Regular
# 2            FDN15       17.500          Low Fat
# 3            FDX07       19.200          Regular
# 4            NCD19        8.930          Low Fat
# 5            FDP36       10.395          Regular
# 6            FDO10       13.650          Regular
# 7            FDP10          NaN          Low Fat
# 8            FDH17       16.200          Regular
# 9            FDU28       19.200          Regular
# 10           FDY07       11.800          Low Fat
# 11           FDA03       18.500          Regular
# 12           FDX32       15.100          Regular
# 13           FDS46       17.600          Regular
# 14           FDF32       16.350          Low Fat
# 15           FDP49        9.000          Regular
# 16           NCB42       11.800          Low Fat
# 17           FDP49        9.000          Regular
# ...

# %%
data = pd.read_excel("/content/Excel/1998.xlsx")
data.head()
# Out:
#    Years    Product  Price
# 0   1998  Fast Food    200
# 1   1998      Sweet    150
# 2   1998  Fast Food    100
# 3   1998  Fast Food    250
# 4   1998  Fast Food    260

# %%
data = pd.read_excel(r"/content/Excel/1998.xlsx",sheet_name = "1998")
data.head()
# Out:
#    Years    Product  Price
# 0   1998  Fast Food    200
# 1   1998      Sweet    150
# 2   1998  Fast Food    100
# 3   1998  Fast Food    250
# 4   1998  Fast Food    260

# %%
data = pd.read_excel(r"/content/Excel/1998.xlsx",sheet_name = "1998")
data.tail()
# Out:
#     Years    Product  Price
# 15   1998      Sweet    210
# 16   1998      Sweet    250
# 17   1998  Fast Food    120
# 18   1998      Sweet    159
# 19   1998  Fast Food    160

# %%
df1 = pd.read_excel(r"/content/Excel/srishti.xlsx",sheet_name = "1998")
df1.tail()
# Out:
#     Years         Product  Price
# 16   1998           Sweet    250
# 17   1998       Fast Food    120
# 18   1998           Sweet    159
# 19   1998       Fast Food    160
# 20   1998  Gajar ka halwa    350

# %%
skip_sheet = pd.read_excel(r"/content/Excel/srishti.xlsx",skiprows = 5)
skip_sheet.head()
# Out:
#    1998  Fast Food  260
# 0  1998      Sweet  230
# 1  1998      Sweet  210
# 2  1998  Fast Food  120
# 3  1998      Sweet  150
# 4  1998  Fast Food  160

# %%
import glob
import pandas as pd

files = glob.glob("/content/Excel/Years/*.xlsx")

for file in files:
  print(file)
#create an empty Dataframe to store the data
all_data = pd.DataFrame()

for file in files:
  df = pd.read_excel(file)
  all_data = all_data._append(df,ignore_index = True)

#Display the combined dataframe
print(all_data)
type(all_data)
all_data.head()
# Out:
# /content/Excel/Years/1998.xlsx
# /content/Excel/Years/1995.xlsx
# /content/Excel/Years/1997.xlsx
# /content/Excel/Years/1996.xlsx
#     Years    Product  Price
# 0    1998  Fast Food    200
# 1    1998      Sweet    150
# 2    1998  Fast Food    100
# 3    1998  Fast Food    250
# 4    1998  Fast Food    260
# ..    ...        ...    ...
# 75   1996      Sweet    210
# 76   1996      Sweet    250
# 77   1996  Fast Food    120
# 78   1996      Sweet    159
# 79   1996  Fast Food    160
#
# [80 rows x 3 columns]
#    Years    Product  Price
# 0   1998  Fast Food    200
# 1   1998      Sweet    150
# 2   1998  Fast Food    100
# 3   1998  Fast Food    250
# 4   1998  Fast Food    260

# %% [markdown]
# Reading JSON files

# %%
df = pd.read_json(r'/content/json/1.json')
df.head()
# Out:
#                                                        response
# status                                                      200
# message                                                 success
# error_msg
# total_result                                              10000
# data_result   [{'icmr_id': '7KowBBfisgc+DHpYtjwdnA==', 'clin...

# %%
#Reading a json file
df = pd.read_json(r'/content/json/simple_records.json', lines= True)
df.head()

#lines arrguments is used for the read the arrugument line by line
# Out:
#       name  age grade
# 0    Andew   12     A
# 1   Bhuvan   18     B
# 2  Clinton   11     A
# 3    Drake   12     C
# 4    Eisha   13     B

# %%
df = pd.read_json(r'/content/json/nested.json')
df.head(10)
# Out:
#    student_roll_no                                        details
# 0              101     {'name': 'Andew', 'age': 12, 'grade': 'A'}
# 1              102    {'name': 'Bhuvan', 'age': 18, 'grade': 'B'}
# 2              103   {'name': 'Clinton', 'age': 11, 'grade': 'A'}
# 3              104     {'name': 'Drake', 'age': 12, 'grade': 'C'}
# 4              105     {'name': 'Eisha', 'age': 13, 'grade': 'B'}
# 5              106    {'name': 'Farhan', 'age': 22, 'grade': 'C'}
# 6              107    {'name': 'Garima', 'age': 11, 'grade': 'A'}
# 7              108  {'name': 'Himanshu', 'age': 19, 'grade': 'A'}
# 8              109    {'name': 'Ishaan', 'age': 10, 'grade': 'D'}
# 9              110      {'name': 'Jason', 'age': 9, 'grade': 'B'}

# %%
import json

with open('/content/json/nested.json')as f:
  data = json.load(f)

print(data)
# Out:
# [{'student_roll_no': 101, 'details': {'name': 'Andew', 'age': 12, 'grade': 'A'}}, {'student_roll_no': 102, 'details': {'name': 'Bhuvan', 'age': 18, 'grade': 'B'}}, {'student_roll_no': 103, 'details': {'name': 'Clinton', 'age': 11, 'grade': 'A'}}, {'student_roll_no': 104, 'details': {'name': 'Drake', 'age': 12, 'grade': 'C'}}, {'student_roll_no': 105, 'details': {'name': 'Eisha', 'age': 13, 'grade': 'B'}}, {'student_roll_no': 106, 'details': {'name': 'Farhan', 'age': 22, 'grade': 'C'}}, {'student_roll_no': 107, 'details': {'name': 'Garima', 'age': 11, 'grade': 'A'}}, {'student_roll_no': 108, 'details': {'name': 'Himanshu', 'age': 19, 'grade': 'A'}}, {'student_roll_no': 109, 'details': {'name': 'Ishaan', 'age': 10, 'grade': 'D'}}, {'student_roll_no': 110, 'details': {'name': 'Jason', 'age': 9, 'grade': 'B'}}]

# %%
from pprint import pprint
pprint(data)
# Out:
# [{'details': {'age': 12, 'grade': 'A', 'name': 'Andew'},
#   'student_roll_no': 101},
#  {'details': {'age': 18, 'grade': 'B', 'name': 'Bhuvan'},
#   'student_roll_no': 102},
#  {'details': {'age': 11, 'grade': 'A', 'name': 'Clinton'},
#   'student_roll_no': 103},
#  {'details': {'age': 12, 'grade': 'C', 'name': 'Drake'},
#   'student_roll_no': 104},
#  {'details': {'age': 13, 'grade': 'B', 'name': 'Eisha'},
#   'student_roll_no': 105},
#  {'details': {'age': 22, 'grade': 'C', 'name': 'Farhan'},
#   'student_roll_no': 106},
#  {'details': {'age': 11, 'grade': 'A', 'name': 'Garima'},
#   'student_roll_no': 107},
#  {'details': {'age': 19, 'grade': 'A', 'name': 'Himanshu'},
#   'student_roll_no': 108},
#  {'details': {'age': 10, 'grade': 'D', 'name': 'Ishaan'},
#   'student_roll_no': 109},
#  {'details': {'age': 9, 'grade': 'B', 'name': 'Jason'}, 'student_roll_no': 110}]

# %% [markdown]
# Reading txt files

# %%
#open & read the txt file
with open(r"/content/text/example.txt",'r')as files:
  data = files.read()
  print(data)
# Out:
# TXT test file
# Purpose: Provide example of this file type
# Document file type: TXT
# Version: 1.0
# Remark:
#
# Example content:
# Hello everyone, my name is Sumit Nayek, and I am thrilled to be here today. I hold a Master's degree in Statistics, where I delved deeply into the realms of data analysis and research methodologies. My passion for leveraging cutting-edge technologies led me to specialize in the application of Artificial Intelligence and Machine Learning in biomedical imaging during my research endeavors. I am enthusiastic about exploring the multifaceted role of a Data Scientist and Data Analyst, where I can apply my analytical skills and innovative thinking to derive actionable insights from complex datasets. I look forward to sharing my knowledge and contributing to our collective journey towards data-driven excellence.

# %% [markdown]
# How to subset first N rows based on the position index ?

# %%
data = pd.read_csv("/content/1995.csv")
data.head()
# Out:
#    Years    Product  Price
# 0   1995  Fast Food    200
# 1   1995      Sweet    150
# 2   1995  Fast Food    100
# 3   1995  Fast Food    250
# 4   1995  Fast Food    260

# %%
data.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
#create random list
import random
random_list =[random.randint(1,20) for i in range(20)]
print(random_list)
# Out:
# [6, 17, 3, 15, 7, 6, 20, 8, 17, 19, 6, 18, 6, 2, 4, 20, 6, 15, 11, 5]

# %%
data.index = random_list
data.head()
# Out:
#     Years    Product  Price
# 6    1995  Fast Food    200
# 17   1995      Sweet    150
# 3    1995  Fast Food    100
# 15   1995  Fast Food    250
# 7    1995  Fast Food    260

# %%
data.set_index('Years',drop=True,inplace=True )
data.head()
# Out:
#          Product  Price
# Years
# 1995   Fast Food    200
# 1995       Sweet    150
# 1995   Fast Food    100
# 1995   Fast Food    250
# 1995   Fast Food    260

# %%
data.index
# Out:
# Index([1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995,
#        1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995],
#       dtype='int64', name='Years')

# %%
data.set_index('Product',drop=True,inplace=True )
data.head()
# Out:
#            Price
# Product
# Fast Food    200
# Sweet        150
# Fast Food    100
# Fast Food    250
# Fast Food    260

# %%
data.loc['Fast Food']
# Out:
#            Price
# Product
# Fast Food    200
# Fast Food    100
# Fast Food    250
# Fast Food    260
# Fast Food    120
# Fast Food    160
# Fast Food    140
# Fast Food    190
# Fast Food    123
# Fast Food    120
# Fast Food    160

# %%
data.loc[['Sweet','Fast Food'],'Price']
# Out:
# Product
# Sweet        150
# Sweet        230
# Sweet        210
# Sweet        150
# Sweet        180
# Sweet        130
# Sweet        210
# Sweet        250
# Sweet        159
# Fast Food    200
# Fast Food    100
# Fast Food    250
# Fast Food    260
# Fast Food    120
# Fast Food    160
# Fast Food    140
# Fast Food    190
# Fast Food    123
# Fast Food    120
# Fast Food    160
# Name: Price, dtype: int64

# %%
data.reset_index(inplace=True)
data.head()
# Out:
#    index    Product  Price
# 0      0  Fast Food    200
# 1      1      Sweet    150
# 2      2  Fast Food    100
# 3      3  Fast Food    250
# 4      4  Fast Food    260

# %% [markdown]
# How to subset data based upon value of column

# %%
data[data['Product']=='Sweet']
data.tail()
# Out:
#     index    Product  Price
# 15     15      Sweet    210
# 16     16      Sweet    250
# 17     17  Fast Food    120
# 18     18      Sweet    159
# 19     19  Fast Food    160

# %%
#range 10-15 for positional index just as slicing
data[10:15]
# Out:
#     index    Product  Price
# 10     10  Fast Food    140
# 11     11      Sweet    180
# 12     12  Fast Food    190
# 13     13      Sweet    130
# 14     14  Fast Food    123

# %%
data.iloc[[1,5,4,2,3,6,7,9]]
# Out:
#    index    Product  Price
# 1      1      Sweet    150
# 5      5      Sweet    230
# 4      4  Fast Food    260
# 2      2  Fast Food    100
# 3      3  Fast Food    250
# 6      6      Sweet    210
# 7      7  Fast Food    120
# 9      9  Fast Food    160

# %%
data.iloc[[1,4,5,2],[1]]
# Out:
#      Product
# 1      Sweet
# 4  Fast Food
# 5      Sweet
# 2  Fast Food

# %%
data.iloc[10:15:2]
# Out:
#     index    Product  Price
# 10     10  Fast Food    140
# 12     12  Fast Food    190
# 14     14  Fast Food    123
