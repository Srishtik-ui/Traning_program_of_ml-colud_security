# %% [markdown]
# <a href="https://colab.research.google.com/github/Srishtik-ui/Traning_program_of_ml-colud_security/blob/main/DAy8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.value_counts()
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 4.9           3.1          1.5           0.1          setosa       3
# 5.8           2.7          5.1           1.9          virginica    2
# 4.3           3.0          1.1           0.1          setosa       1
# 4.4           3.2          1.3           0.2          setosa       1
# 4.5           2.3          1.3           0.3          setosa       1
#                                                                   ..
# 7.7           2.6          6.9           2.3          virginica    1
#               2.8          6.7           2.0          virginica    1
#               3.0          6.1           2.3          virginica    1
#               3.8          6.7           2.2          virginica    1
# 7.9           3.8          6.4           2.0          virginica    1
# Name: count, Length: 147, dtype: int64

# %%
#histogram
plt.figure(figsize = (8,6))
df.hist()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x='sepal_length', fill=True)
plt.title('Density Plot of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Density')
plt.show()

# %%
sns.set(style='darkgrid' ,context='talk',palette='rainbow')
numerical=df.select_dtypes('number').columns
for col in numerical:
  fig,ax=plt.subplots(1,3,figsize=(20,4))
  sns.histplot(data=df,x=col,ax=ax[0])
  sns.boxplot(data=df,x=col,ax=ax[1])
  sns.kdeplot(data=df,x=col,ax=ax[2])

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df,hue='species')
plt.legend(bbox_to_anchor=(1,1),loc=2)
plt.show()

# %% [markdown]
# the relation b/w speal length nd speal_width as compare to iris_srtosa is storngly postive which can verify futher by using corealtion matrix.

# %%
sns.scatterplot(x='petal_length',y='petal_width',data=df,hue='species')
plt.legend(bbox_to_anchor=(1,1),loc=2)
plt.show()

# %% [markdown]
# the relation b/w petal_length and petal_width as compare to iris setosa is close to zero which is futher verify by corelation matrix
#
#
# nd for versicolor and virginica the co relation matrix is highly positive may be it become 0.8 verify futher by corelation matrix.

# %%
correlation_matrix = df.corr(numeric_only=True)
display(correlation_matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.pairplot(df,hue='species',height = 5)

# %% [markdown]
# in the graph we get  petal_width of each species linearly just a few part of versicolor and virginica intersect at a point.

# %%
features = df.drop('species', axis = 1)
sns.heatmap(features.corr(method='pearson'),annot=True)
plt.show()

# %% [markdown]
# the interpretation of this variable is the correlation matrix show that the corelation of sepal_length is 1
# nd the correlation of sepal_width and petal_length is 96%.
#
#
# * It gives the exact Value of the correlation of all columns of the IRIS dataset

# %%
from sklearn import datasets

iris = datasets.load_iris()
sepal_length = iris.data[:, 0]

plt.boxplot(sepal_length, labels = ['Sepal Length'])
plt.ylabel('cm')
plt.title('Box Plot of sepal length')
plt.show()
# Out:
# /tmp/ipython-input-2312653679.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(sepal_length, labels = ['Sepal Length'])

# %%
species = iris.target_names
species_counts = np.bincount(iris.target)
plt.figure(figsize = (8,8))
plt.pie(species_counts, labels = species, autopct = '%1.1f%%', startangle = 90)
plt.title('Pie Chart of Iris Species')
plt.show()

# %% [markdown]
# Bivarite Graph

# %%
plt.figure(figsize = (8,6))
plt.scatter(iris.data[:,0],iris.data[:,2], c = iris.target)
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.title('Scatter Plot of Sepal Length vs Petal Length')
plt.show()

# %% [markdown]
# This graph show the shape of patel length and sepal length

# %%
plt.figure(figsize= (8,6))
sns.boxplot(x = 'species', y = 'sepal_width', data = df, palette= "viridis")
plt.xlabel('Species')
plt.ylabel('sepal width(cm)')
plt.title('Sepal Width by Species')
plt.show()
# Out:
# /tmp/ipython-input-1891304341.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'species', y = 'sepal_width', data = df, palette= "viridis")

# %%
iris = datasets.load_iris()

df1 = pd.DataFrame(iris.data, columns = iris.feature_names)
df1['species'] = iris.target_names[iris.target]

plt.figure(figsize= (8,6))
for species in iris.target_names:
   sns.kdeplot(data = df1[df1['species'] == species], x = 'sepal length (cm)', label = species, fill = True)
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Density')
plt.title('Distribution of Sepal Length by Species')
plt.legend()
plt.show()

# %% [markdown]
# **Decision Tree**

# %%
# in decision tree we don't need any assumption.
#difference b/w parametric model nd non paramatric model
#non paramatric model - error are normally distributed.
#random forest : built and merge multiple decision tree to achieve more accurate and stable prediction.

# %% [markdown]
# * Decision Tree
# * A Decision Tree is a supervised machine learning algorithm used for classification and regression
# Works with both numerical and categorical data
#
# * parametric model VS Non parametric model
#
# * Overfitting vs Underfitting
#
# * Entropy
#
# * Information Gain = Entropy (Before split ) - Weighted Avg. Entropy (After split)
#
# *

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

scaler = StandardScaler()
features = df.drop('species', axis = 1)
scaled_features = scaler.fit_transform(features)

X_train, X_test, y_train, y_test = train_test_split(scaled_features, df['species'], test_size = 0.2, random_state = 1)

# %%
x = scaled_features
y = df['species']

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9666666666666667

# %%
x = df.drop(['species'],axis=1)
from sklearn import tree
fig= plt.figure(figsize=(10,10))
dtree = tree.plot_tree(clf,filled=True,feature_names=x.columns,class_names=np.unique(y))

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=2)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9666666666666667

# %%
dtree2 = tree.plot_tree(clf,filled=True,feature_names=x.columns,class_names=np.unique(y))
