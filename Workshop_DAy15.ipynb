# %% [markdown]
# <a href="https://colab.research.google.com/github/Srishtik-ui/Traning_program_of_ml-colud_security/blob/main/Workshop_DAy15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Comparative Look at Cloud Deployment :
# ======================================
#
# * Public Cloud: Service are accessible to the general public
#
# * Private Cloud: Service are accessible only within single org.
#
# * Hybrid Cloud: Micture of public and private cloud
#
# * Community Cloud: Service are accessible to a specific group of org.with shared concerns

# %% [markdown]
# Explaining Colud Service With Pizza
#
# You Make it Home -> Take and Bake -> Pizza Delivery -> Dining Out

# %% [markdown]
# The Cloud Service Stack : Iaas, Paas , and Saas
#
# the three service model are not independent,
#
#
#
# colud client -> SaaS (Software as a Service) -> Paas ( Platform as a Service) -> IaaS (Infrastructure as a Service)

# %% [markdown]
# Infrasturcture as a service
#
# what we get:-
#
# Virtual machine & physical Server
#
# virtual Stroge & Network (VLANs)
#
# Load Balancers, IP Addresses
#
#
#
#
#
# *Benifits
#
# full control of computing resources through administrative access to VMs.
#
#
# Flexiable and efficient.
#
#
# Issue:-
#
#  potential compatibility issues with legacy security, and risk of 'virtual machine sprawl' if not managed properly.
