# %% [markdown]
# <a href="https://colab.research.google.com/github/Srishtik-ui/Traning_program_of_ml-colud_security/blob/main/Workshop_day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data  = pd.read_csv('/content/drive/MyDrive/Reading csv files/1995.csv')
data
# Out:
#     Years    Product  Price
# 0    1995  Fast Food    200
# 1    1995      Sweet    150
# 2    1995  Fast Food    100
# 3    1995  Fast Food    250
# 4    1995  Fast Food    260
# 5    1995      Sweet    230
# 6    1995      Sweet    210
# 7    1995  Fast Food    120
# 8    1995      Sweet    150
# 9    1995  Fast Food    160
# 10   1995  Fast Food    140
# 11   1995      Sweet    180
# 12   1995  Fast Food    190
# 13   1995      Sweet    130
# 14   1995  Fast Food    123
# 15   1995      Sweet    210
# 16   1995      Sweet    250
# 17   1995  Fast Food    120
# 18   1995      Sweet    159
# 19   1995  Fast Food    160

# %%
data = data.sort_values(by=['Price'])
data
# Out:
#     Years    Product  Price
# 2    1995  Fast Food    100
# 7    1995  Fast Food    120
# 17   1995  Fast Food    120
# 14   1995  Fast Food    123
# 13   1995      Sweet    130
# 10   1995  Fast Food    140
# 1    1995      Sweet    150
# 8    1995      Sweet    150
# 18   1995      Sweet    159
# 19   1995  Fast Food    160
# 9    1995  Fast Food    160
# 11   1995      Sweet    180
# 12   1995  Fast Food    190
# 0    1995  Fast Food    200
# 15   1995      Sweet    210
# 6    1995      Sweet    210
# 5    1995      Sweet    230
# 3    1995  Fast Food    250
# 16   1995      Sweet    250
# 4    1995  Fast Food    260

# %%
data.loc[2:4]
# Out:
#     Years    Product  Price
# 2    1995  Fast Food    100
# 7    1995  Fast Food    120
# 17   1995  Fast Food    120
# 14   1995  Fast Food    123
# 13   1995      Sweet    130
# 10   1995  Fast Food    140
# 1    1995      Sweet    150
# 8    1995      Sweet    150
# 18   1995      Sweet    159
# 19   1995  Fast Food    160
# 9    1995  Fast Food    160
# 11   1995      Sweet    180
# 12   1995  Fast Food    190
# 0    1995  Fast Food    200
# 15   1995      Sweet    210
# 6    1995      Sweet    210
# 5    1995      Sweet    230
# 3    1995  Fast Food    250
# 16   1995      Sweet    250
# 4    1995  Fast Food    260

# %%
data.iloc[2:4]
# Out:
#     Years    Product  Price
# 17   1995  Fast Food    120
# 14   1995  Fast Food    123

# %%
data[(data.Price==120)|(data.Product=='Fast Food')]
# Out:
#     Years    Product  Price
# 2    1995  Fast Food    100
# 7    1995  Fast Food    120
# 17   1995  Fast Food    120
# 14   1995  Fast Food    123
# 10   1995  Fast Food    140
# 19   1995  Fast Food    160
# 9    1995  Fast Food    160
# 12   1995  Fast Food    190
# 0    1995  Fast Food    200
# 3    1995  Fast Food    250
# 4    1995  Fast Food    260

# %%
data[(data.Price==120)&(data.Product=='Fast Food')]
# Out:
#     Years    Product  Price
# 7    1995  Fast Food    120
# 17   1995  Fast Food    120

# %%
#The .isin() method in pandas is used to filter a DataFrame by checking if each element in a Series (a column of your DataFrame) is contained in a passed list of values.
data[data.Price.isin([120,123])]
# Out:
#     Years    Product  Price
# 7    1995  Fast Food    120
# 17   1995  Fast Food    120
# 14   1995  Fast Food    123

# %%
df = pd.read_csv("/content/drive/MyDrive/Data for pre-processing-20260107T062258Z-1-001/Data for pre-processing/big_mart_sales.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#select_columns = ['Item_Identifier','Item_Weight','Item_Fat_Content','Item_Visibility','Item_Type','Item_MRP']

#df = df[(df.Outlet_Size =='Medium')&(df.Outlet_Establishment_Year==2009)][select_columns]
#df

# %% [markdown]
# How to select the proper data type of a variable

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.select_dtypes('object')
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.isnull().sum() #both have same work by using isnull() or isna()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.isna()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.loc[df.Item_Weight.isnull()==True]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
x= df.loc[(df.Item_Weight.isnull()==True),'Item_Weight']=df['Item_Weight'].mean()
x
# Out:
# np.float64(12.857645184135976)

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.Outlet_Size.value_counts() #frequency distribution
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
y=df.loc[(df.Outlet_Size.isnull()==True),'Outlet_Size']='Medium'
y
# Out:
# 'Medium'

# %% [markdown]
# Converting cetogrical var into numerical
# why?
#
# because most machine learning algorithms cannot directly process text data. They require numerical input.

# %%
#df = pd.get_dummies(df)
#df

# %% [markdown]
# What is the mean sale for different outlet size and different location type

# %%
select_columns = ['Outlet_Size','Outlet_Location_Type','Item_Outlet_Sales']
df.sort_values(by=['Item_Outlet_Sales'],ascending=False)[select_columns]
# Out:
#      Outlet_Size Outlet_Location_Type  Item_Outlet_Sales
# 7188      Medium               Tier 3         13086.9648
# 5223      Medium               Tier 3         12117.5600
# 1450      Medium               Tier 3         11445.1020
# 4349      Medium               Tier 3         10993.6896
# 6541      Medium               Tier 3         10306.5840
# ...          ...                  ...                ...
# 7388      Medium               Tier 3            35.2874
# 3053       Small               Tier 1            34.6216
# 2571       Small               Tier 1            33.9558
# 6950      Medium               Tier 3            33.2900
# 906       Medium               Tier 3            33.2900
#
# [8523 rows x 3 columns]

# %% [markdown]
# Update the original dataframe to sorted condition

# %%
df.sort_values(by=['Item_Outlet_Sales'],ascending=False,inplace=True)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7188           NCE42    12.857645          Low Fat         0.010551
# 5223           FDQ19    12.857645          Regular         0.014296
# 1450           FDZ20    12.857645          Low Fat         0.000000
# 4349           FDP33    12.857645          Low Fat         0.088840
# 6541           FDI50    12.857645          Regular         0.030693
# ...              ...          ...              ...              ...
# 7388           FDQ47     7.155000          Regular         0.281510
# 3053           NCL41    12.857645          Low Fat         0.073077
# 2571           FDU21    12.857645          Regular         0.134328
# 6950           NCR42     9.105000          Low Fat         0.064411
# 906            DRK12     9.500000          Low Fat         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7188              Household  234.9958            OUT027
# ...

# %%
df1= pd.read_csv("/content/drive/MyDrive/Reading csv files/Years/1995.csv")
df2 = pd.read_csv("/content/drive/MyDrive/Reading csv files/Years/1996.csv")
df3 = pd.read_csv("/content/drive/MyDrive/Reading csv files/Years/1997.csv")
df4 = pd.read_csv("/content/drive/MyDrive/Reading csv files/Years/1998.csv")
data  = [df1,df2,df3,df4]
dfa = pd.concat(data)
print(dfa)
dfa.shape
# Out:
#     Years    Product  Price
# 0    1995  Fast Food    200
# 1    1995      Sweet    150
# 2    1995  Fast Food    100
# 3    1995  Fast Food    250
# 4    1995  Fast Food    260
# ..    ...        ...    ...
# 15   1998      Sweet    210
# 16   1998      Sweet    250
# 17   1998  Fast Food    120
# 18   1998      Sweet    159
# 19   1998  Fast Food    160
#
# [80 rows x 3 columns]
# (80, 3)

# %%
place = pd.DataFrame({'location':['Kolkata','Medinipur','Kolkata','Mednipur','Haldia','Kolkata','Haldia','Delhi','landon','Usa','UK','CP','BGS','Bgp','Kota']})
place
# Out:
#      location
# 0     Kolkata
# 1   Medinipur
# 2     Kolkata
# 3    Mednipur
# 4      Haldia
# 5     Kolkata
# 6      Haldia
# 7       Delhi
# 8      landon
# 9         Usa
# 10         UK
# 11         CP
# 12        BGS
# 13        Bgp
# 14       Kota

# %%
combine = pd.concat([dfa,place],axis=1)
combine
# Out:
#     Years    Product  Price   location
# 0    1995  Fast Food    200    Kolkata
# 1    1995      Sweet    150  Medinipur
# 2    1995  Fast Food    100    Kolkata
# 3    1995  Fast Food    250   Mednipur
# 4    1995  Fast Food    260     Haldia
# ..    ...        ...    ...        ...
# 15   1998      Sweet    210        NaN
# 16   1998      Sweet    250        NaN
# 17   1998  Fast Food    120        NaN
# 18   1998      Sweet    159        NaN
# 19   1998  Fast Food    160        NaN
#
# [80 rows x 4 columns]

# %% [markdown]
# Simple agregation function

# %%
df1.Price.mean()
# Out:
# np.float64(174.6)

# %%
print(df.Price.median())
print(df.Price.mode())
# Out:
# 160.0
# 0    120
# 1    150
# 2    160
# 3    210
# 4    250
# Name: Price, dtype: int64

# %%
df1.describe() #used for summeried the data
# Out:
#         Years       Price
# count    20.0   20.000000
# mean   1995.0  174.600000
# std       0.0   48.344596
# min    1995.0  100.000000
# 25%    1995.0  137.500000
# 50%    1995.0  160.000000
# 75%    1995.0  210.000000
# max    1995.0  260.000000

# %%
x = df1.groupby(['Product'])
x.mean()['Price']
# Out:
# Product
# Fast Food    165.727273
# Sweet        185.444444
# Name: Price, dtype: float64

# %%
# Out:
#     Years    Product  Price
# 0    1995  Fast Food    200
# 1    1995      Sweet    150
# 2    1995  Fast Food    100
# 3    1995  Fast Food    250
# 4    1995  Fast Food    260
# ..    ...        ...    ...
# 15   1998      Sweet    210
# 16   1998      Sweet    250
# 17   1998  Fast Food    120
# 18   1998      Sweet    159
# 19   1998  Fast Food    160
#
# [80 rows x 3 columns]

# %%
cp = pd.read_csv("/content/drive/MyDrive/Data for pre-processing-20260107T062258Z-1-001/Data for pre-processing/big_mart_sales.csv")
cp
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
x = cp.groupby(['Outlet_Size','Item_Type'])['Item_MRP'].mean() #type error come first because the mean works on numerical var so we use Item_MRP
x
# Out:
# Outlet_Size  Item_Type
# High         Baking Goods             129.202044
#              Breads                   133.758960
#              Breakfast                147.490585
#              Canned                   135.442708
#              Dairy                    153.509173
#              Frozen Foods             136.829250
#              Fruits and Vegetables    145.572870
#              Hard Drinks              141.927522
#              Health and Hygiene       135.110980
#              Household                147.097522
#              Meat                     137.244790
#              Others                   132.576613
#              Seafood                  134.864240
#              Snack Foods              145.847086
#              Soft Drinks              131.758473
#              Starchy Foods            158.157074
# Medium       Baking Goods             126.178568
#              Breads                   140.861039
#              Breakfast                134.537511
# ...

# %%
pd.pivot_table(cp,index=['Outlet_Size','Item_Type'],values='Item_MRP',aggfunc='mean') # just use for easy to understand
# Out:
#                                      Item_MRP
# Outlet_Size Item_Type
# High        Baking Goods           129.202044
#             Breads                 133.758960
#             Breakfast              147.490585
#             Canned                 135.442708
#             Dairy                  153.509173
#             Frozen Foods           136.829250
#             Fruits and Vegetables  145.572870
#             Hard Drinks            141.927522
#             Health and Hygiene     135.110980
#             Household              147.097522
#             Meat                   137.244790
#             Others                 132.576613
#             Seafood                134.864240
#             Snack Foods            145.847086
#             Soft Drinks            131.758473
#             Starchy Foods          158.157074
# Medium      Baking Goods           126.178568
#             Breads                 140.861039
#             Breakfast              134.537511
# ...

# %%
pd.crosstab(cp.Outlet_Size,cp.Item_Type)
# Out:
# Item_Type    Baking Goods  Breads  Breakfast  Canned  Dairy  Frozen Foods  \
# Outlet_Size
# High                   73      25         13      65     80            92
# Medium                203      83         36     217    218           274
# Small                 187      71         30     189    198           249
#
# Item_Type    Fruits and Vegetables  Hard Drinks  Health and Hygiene  \
# Outlet_Size
# High                           142           23                  61
# Medium                         413           75                 170
# Small                          328           50                 136
#
# Item_Type    Household  Meat  Others  Seafood  Snack Foods  Soft Drinks  \
# Outlet_Size
# High               103    41      16        5          125           49
# Medium             289   149      52       21          408          137
# Small              257   119      55       20          335          126
#
# Item_Type    Starchy Foods
# Outlet_Size
# ...
